# %%
import pandas as pd

# %%
df = pd.read_csv("organizations-100000.csv")

# %%
df
# Out:
#         Index  Organization Id                      Name  \
# 0           1  8cC6B5992C0309c               Acevedo LLC
# 1           2  ec094061FeaF7Bc            Walls-Mcdonald
# 2           3  DAcC5dbc58946A7               Gregory PLC
# 3           4  8Dd7beDa37FbeD0  Byrd, Patterson and Knox
# 4           5  a3b5c54AEC163e4          Mcdowell-Hopkins
# ...       ...              ...                       ...
# 99995   99996  3E5e8e6a60CF9FF                Frey Group
# 99996   99997  BdfAa2aE00DaE79                Lloyd-Dyer
# 99997   99998  5c3a2EBDeC9B25b           Levine and Sons
# 99998   99999  c58E390b3dd61a5              Martinez PLC
# 99999  100000  14ab658Ad57Fcfd               Esparza Inc
#
#                             Website                        Country  \
# 0          https://www.donovan.com/  Holy See (Vatican City State)
# 1          http://arias-willis.net/                      Lithuania
# 2      http://www.lynch-hoover.net/                        Tokelau
# ...

# %%
df.head()
# Out:
#    Index  Organization Id                      Name  \
# 0      1  8cC6B5992C0309c               Acevedo LLC
# 1      2  ec094061FeaF7Bc            Walls-Mcdonald
# 2      3  DAcC5dbc58946A7               Gregory PLC
# 3      4  8Dd7beDa37FbeD0  Byrd, Patterson and Knox
# 4      5  a3b5c54AEC163e4          Mcdowell-Hopkins
#
#                         Website                        Country  \
# 0      https://www.donovan.com/  Holy See (Vatican City State)
# 1      http://arias-willis.net/                      Lithuania
# 2  http://www.lynch-hoover.net/                        Tokelau
# 3  https://www.james-velez.net/                    Netherlands
# 4           http://fuentes.com/                        Mayotte
#
#                             Description  Founded                     Industry  \
# 0      Multi-channeled bottom-line core     2019  Graphic Design / Web Design
# 1     Compatible encompassing groupware     2005                    Utilities
# ...

# %%
df.head(100)
# Out:
#     Index  Organization Id                      Name  \
# 0       1  8cC6B5992C0309c               Acevedo LLC
# 1       2  ec094061FeaF7Bc            Walls-Mcdonald
# 2       3  DAcC5dbc58946A7               Gregory PLC
# 3       4  8Dd7beDa37FbeD0  Byrd, Patterson and Knox
# 4       5  a3b5c54AEC163e4          Mcdowell-Hopkins
# ..    ...              ...                       ...
# 95     96  EEBdB9Dc21D2d0c              Horne-Murphy
# 96     97  6b00e6ccB2aAbf4            House and Sons
# 97     98  B8Ddf23a87Ff19c     Key, Beard and Greene
# 98     99  c9Cdf92BC6f0Beb             Nguyen-Medina
# 99    100  4CA68CcA2fCE2B9   Wilkinson, Day and Chen
#
#                           Website                        Country  \
# 0        https://www.donovan.com/  Holy See (Vatican City State)
# 1        http://arias-willis.net/                      Lithuania
# 2    http://www.lynch-hoover.net/                        Tokelau
# ...

# %%
df.tail()
# Out:
#         Index  Organization Id             Name                  Website  \
# 99995   99996  3E5e8e6a60CF9FF       Frey Group        http://haney.com/
# 99996   99997  BdfAa2aE00DaE79       Lloyd-Dyer      https://farmer.org/
# 99997   99998  5c3a2EBDeC9B25b  Levine and Sons  http://www.andrade.org/
# 99998   99999  c58E390b3dd61a5     Martinez PLC   https://www.glass.biz/
# 99999  100000  14ab658Ad57Fcfd      Esparza Inc     https://thomas.info/
#
#                     Country                               Description  \
# 99995               Bolivia  Multi-channeled 6thgeneration monitoring
# 99996                 Samoa           Seamless value-added encryption
# 99997                 Congo              Sharable impactful structure
# 99998               Belarus         Front-line responsive flexibility
# 99999  Netherlands Antilles            Customizable secondary adapter
#
#        Founded                               Industry  Number of employees
# ...

# %%
df.tail(100)
# Out:
#         Index  Organization Id                           Name  \
# 99900   99901  D5d06cc84782ECA        Ayers, Perkins and Ross
# 99901   99902  3beb5EeA28c8F4a                       Ware Inc
# 99902   99903  69Edf4FcbF8447D                  Mendoza-Salas
# 99903   99904  10E0AEaD8a3830B     Hanna, Oneill and Robinson
# 99904   99905  Bb68F9D2d7F45bE  Holloway, Beltran and Patrick
# ...       ...              ...                            ...
# 99995   99996  3E5e8e6a60CF9FF                     Frey Group
# 99996   99997  BdfAa2aE00DaE79                     Lloyd-Dyer
# 99997   99998  5c3a2EBDeC9B25b                Levine and Sons
# 99998   99999  c58E390b3dd61a5                   Martinez PLC
# 99999  100000  14ab658Ad57Fcfd                    Esparza Inc
#
#                           Website                   Country  \
# 99900  https://proctor-moses.com/                      Fiji
# 99901        http://www.love.biz/                  Cameroon
# ...

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Index                100000 non-null  int64
#  1   Organization Id      100000 non-null  object
#  2   Name                 100000 non-null  object
#  3   Website              100000 non-null  object
#  4   Country              100000 non-null  object
#  5   Description          100000 non-null  object
#  6   Founded              100000 non-null  int64
#  7   Industry             100000 non-null  object
#  8   Number of employees  100000 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 6.9+ MB

# %%
df.describe()
# Out:
#                Index        Founded  Number of employees
# count  100000.000000  100000.000000        100000.000000
# mean    50000.500000    1995.735170          5003.959280
# std     28867.657797      15.097952          2889.465063
# min         1.000000    1970.000000             1.000000
# 25%     25000.750000    1983.000000          2508.000000
# 50%     50000.500000    1996.000000          4998.000000
# 75%     75000.250000    2009.000000          7503.000000
# max    100000.000000    2022.000000          9999.000000

# %%
df.Founded.hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(df.Founded)
# Out:
# <Axes: ylabel='Founded'>

# %%
df= df[df.Founded<=1000000]

# %%
df.shape
# Out:
# (100000, 9)

# %%
df= df[df.Founded<=2000]

# %%
df.shape
# Out:
# (59162, 9)

# %%
sns.boxplot(df.Founded)
# Out:
# <Axes: ylabel='Founded'>

# %%
df.Founded.hist()
# Out:
# <Axes: >

# %%
df.Country.hist()
# Out:
# <Axes: >

# %%
df = df[['Organization Id','Name','Website','Country','Founded','Industry']]

# %%
df.shape
# Out:
# (59162, 6)

# %%
df.isna().sum()
# Out:
# Organization Id    0
# Name               0
# Website            0
# Country            0
# Founded            0
# Industry           0
# dtype: int64

# %%
df.head()
# Out:
#     Organization Id                          Name  \
# 3   8Dd7beDa37FbeD0      Byrd, Patterson and Knox
# 5   fDfEBeFDaEb59Af               Hayden and Sons
# 7   B1D4c5CA34f9992       Barajas, Baird and Shaw
# 8   Cfa1a44106faD4B  Lucas, Galloway and Benjamin
# 10  94B9bEedc626820            Underwood-Mitchell
#
#                           Website                   Country  Founded  \
# 3    https://www.james-velez.net/               Netherlands     1982
# 5   https://www.shaw-mooney.info/                    Belize     1978
# 7   http://www.jordan-harvey.com/  United States of America     2000
# 8              http://silva.info/            Western Sahara     1990
# 10       https://www.leonard.com/                     Italy     1992
#
#            Industry
# 3         Furniture
# 5         Insurance
# 7         Wholesale
# 8   Retail Industry
# 10         Fine Art

# %%
df = df.fillna(df.median)

# %%
df.head()
# Out:
#     Organization Id                          Name  \
# 3   8Dd7beDa37FbeD0      Byrd, Patterson and Knox
# 5   fDfEBeFDaEb59Af               Hayden and Sons
# 7   B1D4c5CA34f9992       Barajas, Baird and Shaw
# 8   Cfa1a44106faD4B  Lucas, Galloway and Benjamin
# 10  94B9bEedc626820            Underwood-Mitchell
#
#                           Website                   Country  Founded  \
# 3    https://www.james-velez.net/               Netherlands     1982
# 5   https://www.shaw-mooney.info/                    Belize     1978
# 7   http://www.jordan-harvey.com/  United States of America     2000
# 8              http://silva.info/            Western Sahara     1990
# 10       https://www.leonard.com/                     Italy     1992
#
#            Industry
# 3         Furniture
# 5         Insurance
# 7         Wholesale
# 8   Retail Industry
# 10         Fine Art

# %%
df.isin([0]).sum()
# Out:
# Organization Id    0
# Name               0
# Website            0
# Country            0
# Founded            0
# Industry           0
# dtype: int64
